# %%
import pandas as pd

countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
import pandas as pd

countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %% [markdown]
# В аптеку поступают партии лекарств. Их названия находятся в списке names, количество единиц товара находится в списке counts.
#
# Например:
#
# names=['chlorhexidine', 'cyntomycin', 'afobazol']
# counts=[15, 18, 7]
# Напишите функцию create_medications(names, counts), создающую Series medications, индексами которого являются названия лекарств names, а значениями — их количество в партии counts.
#
# Также напишите функцию get_percent(medications, name), которая возвращает долю товара с именем name от общего количества товаров в партии в процентах.

# %%
import pandas as pd

def create_medications(names, counts):
    medications = pd.Series(
        index = names,
        data = counts,
           )
    return medications
    
    
names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

def get_percent(medications, name):
    total_count = medications.sum()
    percent = (medications[name] / total_count) * 100
    return percent

medications = create_medications(names, counts)

percent = get_percent(medications, 'afobazol')
print(percent)
# Out:
# 17.5

# %% [markdown]
# countries_df = pd.DataFrame(
#     data = [
#         ['Англия', 56.29, 133396],
#         ['Канада', 38.05, 9984670],
#         ['США', 322.28, 9826630],
#         ['Россия', 146.24, 17125191],
#         ['Украина', 45.5, 603628],
#         ['Беларусь', 9.5, 207600],
#         ['Казахстан', 17.04, 2724902]
#     ],
#     columns= ['country', 'population', 'square'],
#     index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
# )
# display(countries_df)
#
# Вы работаете аналитиком в компании ScienceYou. Ваша задача — проанализировать чистую прибыль.
#
# Доходы (income), расходы (expenses) и годы (years), соответствующие им, предоставлены вам в виде списков.
#
# Например:
#
#
# income = [478, 512, 196]
# expenses = [156, 130, 270]
# years = [2018, 2019, 2020]
# Создайте функцию create_companyDF(income, expenses, years), которая возвращает DataFrame, составленный из входных данных со столбцами Income и Expenses и индексами, соответствующими годам рассматриваемого периода.
#
# Пример такого DataFrame представлен ниже.
#
#
#     Income  Expenses
# 2018    478     156
# 2019    512     130
# 2020    196     270
# Также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанными в таблице df, за год year.
#
# Примечание. Если информация за запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.

# %%
def create_companyDF(income, expenses, years):
    data = {'Income': income, 'Expenses': expenses}
    df = pd.DataFrame(data, index=years)
    return df

def get_profit(df, year):
    if year in df.index:
        profit = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
        return profit
    else:
        return None

income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]
df = create_companyDF(income, expenses, years)
print(create_companyDF(income, expenses, years), get_profit(df, 2018))
companies = create_companyDF(income, expenses, years)
companies.to_csv('data/companies.csv', index=True, sep=';')
# Out:
#       Income  Expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270 322

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
countries_data = pd.read_csv('data/companies.csv', sep=';')
display(countries_data)
# Out:
#    Unnamed: 0  Income  Expenses
# 0        2018     478       156
# 1        2019     512       130
# 2        2020     196       270

# %%
price_15 = melb_data.loc[15, 'Price']
print(price_15)
print('-'*20)
date_90 = melb_data.loc[90, 'Date']
print(date_90)
print('-'*20)
area_3521 = melb_data.loc[3521, 'Landsize']
area_1690 = melb_data.loc[1690, 'Landsize']
ratio = area_3521 / area_1690
rounded_ratio = round(ratio)
print(rounded_ratio)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mrmon\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
display(melb_data.head(6))
display(melb_data.tail(2))
melb_data.info()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
# 5      5  Abbotsford    129 Charles St      2    h   941000.0      S  Jellis
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe(include = ['object']).loc[:, ['Type']]

melb_data['Type'].value_counts()
# Out:
# Type
# h    9449
# u    3017
# t    1114
# Name: count, dtype: int64

# %%
import pandas as pd

melb_data = pd.read_csv('data\melb_data.csv', sep=',')

print(melb_data['Bedroom'].mode())
# Out:
# 0    3.0
# Name: Bedroom, dtype: float64

# %%
landsize_median = melb_data['BuildingArea'].median() 
landsize_mean =  melb_data['BuildingArea'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# Out:
# 0.09764079662364533

# %%
display(melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0])
display(melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0])
display(melb_data[melb_data['BuildingArea'] == 0]['Price'].min())
display(melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))]['Price'].mean())
area_with_most_villas = melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].value_counts().idxmax()
display(area_with_most_villas)
# Out:
# 5
# 3
# 412500.0
# 769238.6363636364
# 'Northern Metropolitan'

# %%
import pandas as pd

student_data = pd.read_csv('data\students_performance.csv', sep=',')

display(student_data['writing score'].iloc[155])
student_data.info()
display(student_data['math score'].mean())
display(student_data['race/ethnicity'].mode())
course_complete = student_data[student_data['test preparation course'] == 'completed']['reading score'].mean()
display(course_complete)
display(student_data[(student_data['math score'] == 0)].shape[0])
payed_lunch = student_data[student_data['lunch'] == 'standard']['math score'].mean()
reduced_lunch = student_data[student_data['lunch'] == 'free/reduced']['math score'].mean()
display(payed_lunch, reduced_lunch)

bachelors_degree_count = student_data['parental level of education'].value_counts()["bachelor's degree"]
total_students = student_data['parental level of education'].count()

percentage_bachelors_degree = (bachelors_degree_count / total_students) * 100

rounded_percentage_bachelors_degree = round(percentage_bachelors_degree)
display(rounded_percentage_bachelors_degree)

writing_median = student_data[student_data['race/ethnicity'] == 'group A']['writing score'].median() 
writing_mean = student_data[student_data['race/ethnicity'] == 'group C']['writing score'].mean()
print(writing_median - writing_mean)

# %%
import pandas as pd

melb_data_ps = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data_ps.head()
melb_df = melb_data_ps.copy()
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()

total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)

melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])

diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %% [markdown]
# Напишите функцию delete_columns(df, col=[]), которая удаляет столбцы из DataFrame и возвращает новую таблицу. Если одного из указанных столбцов не существует в таблице, то функция должна возвращать None.

# %%
import pandas as pd

def delete_columns(df, col=[]):
    df = df.drop([col], axis=1)
    return df

customer_df = pd.DataFrame({
        'number': [0, 1, 2, 3, 4],
        'cust_id': [128, 1201, 9832, 4392, 7472],
        'cust_age': [13, 21, 19, 21, 60],
        'cust_sale': [0, 0, 0.2, 0.15, 0.3],
        'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
        'cust_order': [1400, 14142, 900, 1240, 8430]
    })

display(delete_columns(customer_df, 'number'))
# Out:
#    cust_id  cust_age  cust_sale  cust_year_birth  cust_order
# 0      128        13       0.00             2008        1400
# 1     1201        21       0.00             2000       14142
# 2     9832        19       0.20             2002         900
# 3     4392        21       0.15             2000        1240
# 4     7472        60       0.30             1961        8430

# %%
import pandas as pd

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
millions_people = countries_df['population']*1000000
average_population = millions_people/countries_df['square']
mean_population = average_population.mean()
display(mean_population)
# Out:
# 84.93080566562001

# %%
import pandas as pd
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
voc_sale = melb_df[(melb_df['WeekdaySale'] == 5) | (melb_df['WeekdaySale'] == 6)].shape[0]

display(voc_sale)
# Out:
# 12822

# %%
import pandas as pd

ufo_vs_america = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', sep=',')
display(ufo_vs_america)

ufo_vs_america['Time'] = pd.to_datetime(ufo_vs_america['Time'])

ufo_vs_america['Time'] = ufo_vs_america['Time'].dt.year
ufo_vs_america['Time'].value_counts(normalize=True)

# Преобразование столбца "Time" в формат datetime
ufo_vs_america['Time'] = pd.to_datetime(ufo_vs_america['Time'])
ufo_vs_america_copy = ufo_vs_america.copy()

# Отфильтровать данные для штата Невада (NV)
nevada_data = ufo_vs_america_copy[ufo_vs_america_copy['State'] == 'NV']

# Вычислить разницу между двумя соседними датами в столбце "Time"
nevada_data['Time_diff'] = nevada_data['Time'].diff()

# Вычислить средний интервал времени (в днях) между двумя последовательными случаями наблюдения НЛО в штате Невада (NV)
avg_interval = nevada_data['Time_diff'].mean().days

print(average_interval)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
import pandas as pd

def get_weekend(weekday):
    if weekday == 5 or weekday == 6:
        return 1
    else:
        return 0

melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
weekend_mean_price = round(melb_df[melb_df['Weekend'] == 1]['Price'].mean())

top_sellers = melb_df['SellerG'].value_counts().nlargest(49).index

# Замена компаний, не являющихся самыми популярными, на 'other'
melb_df.loc[~melb_df['SellerG'].isin(top_sellers), 'SellerG'] = 'other'

# Получение минимальной цены объектов, проданных компанией 'Nelson'
nelson_min_price = melb_df.loc[melb_df['SellerG'] == 'Nelson', 'Price'].min()

# Получение минимальной цены объектов, проданных компаниями 'other'
other_min_price = melb_df.loc[melb_df['SellerG'] == 'other', 'Price'].min()

# Расчет отношения минимальной цены объектов, проданных компанией 'Nelson'
# к минимальной цене объектов, проданных компаниями 'other'
ratio = nelson_min_price / other_min_price

# Округление ответа до десятых
rounded_ratio = round(ratio, 1)

display(rounded_ratio)

# display(melb_df.info())
# Out:
# 1.3

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes)     # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
# display(unique_counts)

cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
# display(melb_df.info())

print(melb_df['Regionname'].cat.codes)

melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})
display(melb_df['Type'])

popular_suburbs = melb_df['Suburb'].value_counts().head(119).index.tolist()

# Заменить остальные пригороды на 'other'
melb_df.loc[~melb_df['Suburb'].isin(popular_suburbs), 'Suburb'] = 'other'

# Привести данные в столбце Suburb к категориальному типу
melb_df['Suburb'] = melb_df['Suburb'].astype('category')

# Вывести обновленные данные
print(melb_df.info())
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    4
# 13576    6
# 13577    6
# 13578    6
# 13579    6
# Length: 13580, dtype: int8
# 0        house
# 1        house
# 2        house
# 3        house
# 4        house
#          ...
# 13575    house
# 13576    house
# 13577    house
# 13578    house
# 13579    house
# Name: Type, Length: 13580, dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Address          13580 non-null  object
#  2   Rooms            13580 non-null  int64
#  3   Type             13580 non-null  category
#  4   Price            13580 non-null  float64
#  5   Method           13580 non-null  category
# ...

# %%
import pandas as pd

citibike_df = pd.read_csv('data/citibike-tripdata.csv', sep=',')
citibike_df = citibike_df.drop(['start station id', 'end station id'], axis=1)
citibike_df['age'] = 2018 - citibike_df['birth year']
citibike_df = citibike_df.drop(['birth year'], axis=1)
age = citibike_df[citibike_df['age']>60].shape[0]
citibike_df['starttime'] = pd.to_datetime(citibike_df['starttime'])
citibike_df['stoptime'] = pd.to_datetime(citibike_df['stoptime'])
citibike_df['trip duration'] = citibike_df['stoptime']-citibike_df['starttime']

citibike_df['weekday'] = citibike_df['starttime'].dt.dayofweek
def get_weekend(weekday):
    if weekday == 5 or weekday == 6:
        return 1
    else:
        return 0

citibike_df['weekend'] = citibike_df['weekday'].apply(get_weekend)
def get_time_of_day(time):
    if 0 <= time <= 6:
        return 'night'
    elif 6 < time <= 12:
        return 'morning'
    elif 12 < time <= 18:
        return 'day'
    elif 18 < time <= 23:
        return 'evening'

citibike_df['time_of_day'] = citibike_df['starttime'].dt.hour.apply(get_time_of_day)
a = citibike_df[citibike_df['time_of_day'] == 'day'].shape[0]
b = citibike_df[citibike_df['time_of_day'] == 'night'].shape[0]
print(round(a / b))


display(citibike_df['weekend'].sum())
# Out:
# 9
# 115135

# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
melb_df['Quarter'] = melb_df['Date'].dt.quarter
melb_df['Quarter'].value_counts().sort_values(ascending=False)

unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes)     # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
# display(unique_counts)

cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
# display(melb_df.info())

melb_df['AreaRatio'].sort_values(ascending=[True], ignore_index=True)
melb_df['BuildingArea'].loc[1558]

filtered = melb_df[(melb_df['Rooms'] > 2) & (melb_df['Type'] == 'townhouse')].copy()

filtered.sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
)

display(filtered)

# melb_df.groupby('Regionname')['Lattitude'].std()

melb_df['Date'] = pd.to_datetime(melb_df['Date'])

filtered_data = melb_df[(melb_df['Date'] >= '2017-05-01') & (melb_df['Date'] <= '2017-09-01')]
revenue_by_company = filtered_data.groupby('SellerG')['Price'].sum()
sorted_revenue = revenue_by_company.sort_values()
company_with_min_revenue = sorted_revenue.index[0]

display(company_with_min_revenue)

sellers = melb_df.pivot_table(
    values='Price',
    index=['SellerG','Type'],
    columns='Regionname',
    aggfunc=['median','max'],
    fill_value=0
)

pivot_table = pd.pivot_table(melb_df, values='Price', index='SellerG', columns='Type', aggfunc='median')

max_price_agency = pivot_table['unit'].idxmax()

print(max_price_agency)
display(sellers)
# Out:
#                Suburb  Rooms       Type      Price Method   SellerG  \
# 21         Abbotsford      3  townhouse   900000.0      S     other
# 38       Airport West      3  townhouse   840000.0     PI    Nelson
# 42       Airport West      3  townhouse   700000.0      S      Brad
# 56       Airport West      3  townhouse   700000.0     PI      Brad
# 67       Airport West      3  townhouse   540000.0     SP    Nelson
# ...               ...    ...        ...        ...    ...       ...
# 13437           other      4  townhouse   655000.0      S    Nelson
# 13485           other      4  townhouse  1655000.0      S    Buxton
# 13504  Mount Waverley      3  townhouse  1035000.0     SP   McGrath
# 13521  Port Melbourne      4  townhouse  2455000.0     SP  Marshall
# 13526       Reservoir      3  townhouse   640000.0     PI       Ray
#
#             Date  Distance  Postcode  Bedroom  ...             Regionname  \
# 21    2017-03-18       2.5      3067        3  ...  Northern Metropolitan
# ...

# %%
import pandas as pd

movies_df = pd.read_csv('data/movies.csv')
ratings_1_df = pd.read_csv('data/ratings1.csv')
ratings_2_df = pd.read_csv('data/ratings2.csv')
dates_df = pd.read_csv('data/dates.csv')

dates_df['date'] = pd.to_datetime(dates_df['date'])
dates_df['year'] = dates_df['date'].dt.year

# display(dates_df['year'].value_counts())

ratings = pd.concat([ratings_1_df, ratings_2_df], ignore_index=True)
ratings = ratings.drop_duplicates(ignore_index=True)
ratings_dates = pd.concat([ratings, dates_df], axis=1)

# movie_ratings = ratings_dates.join(movies_df.set_index('movieId'), on='movieId', how='left')
# display(movie_ratings)

merged = ratings_dates.merge(
    movies_df,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date  year  \
# 0       1        1     4.0 2000-07-30 18:45:03  2000
# 1       1        3     4.0 2000-07-30 18:20:47  2000
# 2       1        6     4.0 2000-07-30 18:37:04  2000
# 3       1       47     5.0 2000-07-30 19:03:35  2000
# 4       1       50     5.0 2000-07-30 18:48:51  2000
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
import pandas as pd
import os

def concat_user_files(path):
    file_names = os.listdir(path)
    file_names.sort()
    
    df_list = []
    for file_name in file_names:
        file_path = os.path.join(path, file_name)
        df = pd.read_csv(file_path)
        df_list.append(df)
    
    df_concat = pd.concat(df_list)
    df_concat = df_concat.drop_duplicates().reset_index(drop=True)
    
    return df_concat

# %%
import pandas as pd

rating_movies = pd.read_csv('data/ratings_movies.csv')

#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None
    
rating_movies['year_release'] = rating_movies['title'].apply(get_year_release)
mask = rating_movies['year_release'] == 2010
# display(rating_movies[mask].groupby('genres')['rating'].mean().sort_values())

# rating_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)

rating_movies.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])

mask = rating_movies['year_release'] == 2018
grouped = rating_movies[mask].groupby('genres')['rating'].agg(
    ['mean', 'count']
)
grouped[grouped['count']>10].sort_values(
    by='mean',
    ascending=False
)

rating_movies['date'] = pd.to_datetime(rating_movies['date'])
rating_movies['year_rating'] = rating_movies['date'].dt.year
pivot = rating_movies.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
display(pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# ...

# %%
import pandas as pd

orders_df = pd.read_csv('data/orders.csv')

product_df = pd.read_csv('data/product.csv', sep=';')

orders_products = orders_df.merge(
    product_df, 
    left_on='Product_ID',
    right_on='ID',
    how='left')
orders_products[orders_products['Name'].isna()]

orders_products[orders_products['Отменен'] == 'Да']['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1880\1581557973.py in ?()
# ----> 7 import pandas as pd
#       8
#       9 orders_df = pd.read_csv('data/orders.csv')
#      10
#
# c:\Users\mrmon\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10483         validate: MergeValidate | None = None,
#   10484     ) -> DataFrame:
#   10485         from pandas.core.reshape.merge import merge
#   10486
# > 10487         return merge(
#   10488             self,
#   10489             right,
#   10490             how=how,
#
# ...
